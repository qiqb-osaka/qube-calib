# %%
import ipywidgets as ipw

# %%
import bokeh.io
import bokeh.plotting
from ipywidgets_bokeh import IPyWidget

bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
btn = ipw.Button(description='Randomize')
d = bokeh.plotting.curdoc()
d.add_root(btn)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [6], in <cell line: 3>()
#       1 btn = ipw.Button(description='Randomize')
#       2 d = bokeh.plotting.curdoc()
# ----> 3 d.add_root(btn)
#
# File ~/.local/share/virtualenvs/e7awg_sw-YkKmEDuW/lib/python3.9/site-packages/bokeh/document/document.py:328, in Document.add_root(self, model, setter)
#     325     return
#     327 with self.models.freeze():
# --> 328     self._roots.append(model)
#     330 self.callbacks.trigger_on_change(RootAddedEvent(self, model, setter))
#
# File /usr/lib/python3.9/contextlib.py:124, in _GeneratorContextManager.__exit__(self, type, value, traceback)
#     122 if type is None:
#     123     try:
# --> 124         next(self.gen)
#     125     except StopIteration:
#     126         return False
#
# ...
